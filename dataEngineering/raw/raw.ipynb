# %%
# %pip install pandas psycopg2 sqlalchemy ipykernel
# %pip install psycopg2-binary
# Out:
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (2.2.2)
# Requirement already satisfied: psycopg2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (2.9.9)
# Requirement already satisfied: sqlalchemy in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (2.0.35)
# Requirement already satisfied: ipykernel in /Users/aswath/Library/Python/3.12/lib/python/site-packages (6.29.5)
# Requirement already satisfied: numpy>=1.26.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas) (2024.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from sqlalchemy) (4.12.2)
# Requirement already satisfied: appnope in /Users/aswath/Library/Python/3.12/lib/python/site-packages (from ipykernel) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in /Users/aswath/Library/Python/3.12/lib/python/site-packages (from ipykernel) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/aswath/Library/Python/3.12/lib/python/site-packages (from ipykernel) (1.8.5)
# Requirement already satisfied: ipython>=7.23.1 in /Users/aswath/Library/Python/3.12/lib/python/site-packages (from ipykernel) (8.27.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/aswath/Library/Python/3.12/lib/python/site-packages (from ipykernel) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/aswath/Library/Python/3.12/lib/python/site-packages (from ipykernel) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/aswath/Library/Python/3.12/lib/python/site-packages (from ipykernel) (0.1.7)
# Requirement already satisfied: nest-asyncio in /Users/aswath/Library/Python/3.12/lib/python/site-packages (from ipykernel) (1.6.0)
# Requirement already satisfied: packaging in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from ipykernel) (24.1)
# Requirement already satisfied: psutil in /Users/aswath/Library/Python/3.12/lib/python/site-packages (from ipykernel) (6.0.0)
# Requirement already satisfied: pyzmq>=24 in /Users/aswath/Library/Python/3.12/lib/python/site-packages (from ipykernel) (26.2.0)
# Requirement already satisfied: tornado>=6.1 in /Users/aswath/Library/Python/3.12/lib/python/site-packages (from ipykernel) (6.4.1)
# Requirement already satisfied: traitlets>=5.4.0 in /Users/aswath/Library/Python/3.12/lib/python/site-packages (from ipykernel) (5.14.3)
# Requirement already satisfied: decorator in /Users/aswath/Library/Python/3.12/lib/python/site-packages (from ipython>=7.23.1->ipykernel) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/aswath/Library/Python/3.12/lib/python/site-packages (from ipython>=7.23.1->ipykernel) (0.19.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /Users/aswath/Library/Python/3.12/lib/python/site-packages (from ipython>=7.23.1->ipykernel) (3.0.47)
# Requirement already satisfied: pygments>=2.4.0 in /Users/aswath/Library/Python/3.12/lib/python/site-packages (from ipython>=7.23.1->ipykernel) (2.18.0)
# Requirement already satisfied: stack-data in /Users/aswath/Library/Python/3.12/lib/python/site-packages (from ipython>=7.23.1->ipykernel) (0.6.3)
# Requirement already satisfied: pexpect>4.3 in /Users/aswath/Library/Python/3.12/lib/python/site-packages (from ipython>=7.23.1->ipykernel) (4.9.0)
# Requirement already satisfied: platformdirs>=2.5 in /Users/aswath/Library/Python/3.12/lib/python/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (4.3.6)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /Users/aswath/Library/Python/3.12/lib/python/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/aswath/Library/Python/3.12/lib/python/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/aswath/Library/Python/3.12/lib/python/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /Users/aswath/Library/Python/3.12/lib/python/site-packages (from stack-data->ipython>=7.23.1->ipykernel) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/aswath/Library/Python/3.12/lib/python/site-packages (from stack-data->ipython>=7.23.1->ipykernel) (2.4.1)
# Requirement already satisfied: pure-eval in /Users/aswath/Library/Python/3.12/lib/python/site-packages (from stack-data->ipython>=7.23.1->ipykernel) (0.2.3)
#
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Collecting psycopg2-binary
#   Obtaining dependency information for psycopg2-binary from https://files.pythonhosted.org/packages/18/ca/da384fd47233e300e3e485c90e7aab5d7def896d1281239f75901faf87d4/psycopg2_binary-2.9.9-cp312-cp312-macosx_11_0_arm64.whl.metadata
#   Downloading psycopg2_binary-2.9.9-cp312-cp312-macosx_11_0_arm64.whl.metadata (4.4 kB)
# Downloading psycopg2_binary-2.9.9-cp312-cp312-macosx_11_0_arm64.whl (2.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 25.3 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: psycopg2-binary
# Successfully installed psycopg2-binary-2.9.9
#
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# import pandas as pd
# from sqlalchemy import create_engine

# username = 'postgres'
# password = 'root'
# host = 'localhost'
# port = '5433'
# database = 'final_project'

# connection_string = f'postgresql://{username}:{password}@{host}:{port}/{database}'


# engine = create_engine(connection_string)

# %%
# def creatingRaw():
#     query = 'SELECT * FROM public."Users"'
#     df1 = pd.read_sql(query, engine)
#     df1.to_csv('RAW_Users.csv')

#     query2 = 'SELECT * FROM public."Courses"'
#     df2 = pd.read_sql(query2, engine)
#     df2.to_csv('RAW_Courses.csv')

#     query3 = 'SELECT * FROM public."Feedbacks"'
#     df3 = pd.read_sql(query3, engine)
#     df3.to_csv('RAW_Feedbacks.csv')

#     query4 = 'SELECT * FROM public."TrainingPerformances"'
#     df4 = pd.read_sql(query4, engine)
#     df4.to_csv('RAW_TrainingPerformances.csv')

# %%
# creatingRaw()

# %%
import psycopg2
from psycopg2 import extensions as _ext
import pandas as pd
from sqlalchemy import create_engine
import select

# Database connection details
username = 'postgres'
password = 'root'
host = 'localhost'
port = '5434'
database = 'final_project'

# Creating a connection string for SQLAlchemy
connection_string = f'postgresql://{username}:{password}@{host}:{port}/{database}'
engine = create_engine(connection_string)

# Function to create raw CSV files from the database tables
def creating_raw():
    query = 'SELECT * FROM public."Users"'
    df1 = pd.read_sql(query, engine)
    df1.to_csv('RAW_Users.csv', index=False)

    query2 = 'SELECT * FROM public."Courses"'
    df2 = pd.read_sql(query2, engine)
    df2.to_csv('RAW_Courses.csv', index=False)

    query3 = 'SELECT * FROM public."Feedbacks"'
    df3 = pd.read_sql(query3, engine)
    df3.to_csv('RAW_Feedbacks.csv', index=False)

    query4 = 'SELECT * FROM public."TrainingPerformances"'
    df4 = pd.read_sql(query4, engine)
    df4.to_csv('RAW_TrainingPerformances.csv', index=False)

# Function to listen for notifications from PostgreSQL
def listen_to_notifications():
    # Establish a connection to the PostgreSQL database
    conn = psycopg2.connect(
        dbname=database,
        user=username,
        password=password,
        host=host,
        port=port
    )
    
    # Set the isolation level for the connection
    conn.set_isolation_level(_ext.ISOLATION_LEVEL_AUTOCOMMIT)

    # Create a cursor object using the connection
    cursor = conn.cursor()

    # Execute the LISTEN command to listen for notifications on 'table_update'
    cursor.execute("LISTEN table_update;")
    print("Listening for notifications on table_update...")

    # Infinite loop to continuously listen for notifications
    while True:
        # Wait for notifications with a timeout
        if select.select([conn], [], [], 5) == ([], [], []):
            print("Waiting for notifications...")
        else:
            # Process notifications if any are available
            conn.poll()
            while conn.notifies:
                notify = conn.notifies.pop(0)
                print(f"Notification received: {notify.payload}")
                # Call the function to create raw CSV files
                creating_raw()

if __name__ == "__main__":
    listen_to_notifications()
# Out:
# Listening for notifications on table_update...
# Waiting for notifications...
# Waiting for notifications...
# Waiting for notifications...
# Waiting for notifications...
# Waiting for notifications...
# Waiting for notifications...
# Waiting for notifications...
# Waiting for notifications...
# Waiting for notifications...
# Waiting for notifications...
# Waiting for notifications...
# Waiting for notifications...
# Waiting for notifications...
# Waiting for notifications...
# Waiting for notifications...
# Notification received: TrainingPerformances changed
# Notification received: TrainingPerformances changed
# Waiting for notifications...
# Waiting for notifications...
# Waiting for notifications...
# Waiting for notifications...
# Waiting for notifications...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 72
#      69                 creating_raw()
#      71 if __name__ == "__main__":
# ---> 72     listen_to_notifications()
#
# Cell In[20], line 60, in listen_to_notifications()
#      57 # Infinite loop to continuously listen for notifications
#      58 while True:
#      59     # Wait for notifications with a timeout
# ---> 60     if select.select([conn], [], [], 5) == ([], [], []):
#      61         print("Waiting for notifications...")
#      62     else:
#      63         # Process notifications if any are available
#
# KeyboardInterrupt:
